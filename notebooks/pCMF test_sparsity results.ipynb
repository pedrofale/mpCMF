# %%
# %matplotlib inline

from pCMF.misc import plot_utils

import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns
sns.set_style('whitegrid')

# %% [markdown]
# # Silhouette scores

# %%
silh_pca_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/silh_pca_scores.npy')
silh_gap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/silh_gap_scores.npy')
silh_zigap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/silh_zigap_scores.npy')
silh_szigap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/silh_szigap_scores.npy')

# %%
# Prepare arrays to plot
no_zi_low_sep = [silh_pca_scores[0, 0, :], silh_gap_scores[0, 0, :], silh_zigap_scores[0, 0, :], silh_szigap_scores[0, 0, :]]
no_zi_high_sep = [silh_pca_scores[0, 1, :], silh_gap_scores[0, 1, :], silh_zigap_scores[0, 1, :], silh_szigap_scores[0, 1, :]]

low_zi_low_sep = [silh_pca_scores[1, 0, :], silh_gap_scores[1, 0, :], silh_zigap_scores[1, 0, :], silh_szigap_scores[1, 0, :]]
low_zi_high_sep = [silh_pca_scores[1, 1, :], silh_gap_scores[1, 1, :], silh_zigap_scores[1, 1, :], silh_szigap_scores[1, 1, :]]

high_zi_low_sep = [silh_pca_scores[2, 0, :], silh_gap_scores[2, 0, :], silh_zigap_scores[2, 0, :], silh_szigap_scores[2, 0, :]]
high_zi_high_sep = [silh_pca_scores[2, 1, :], silh_gap_scores[2, 1, :], silh_zigap_scores[2, 1, :], silh_szigap_scores[2, 1, :]]

# %%
# Plot silhouette scores
legend=['PCA',  'GaP', 'ZIGaP', 'SZIGaP']
fig = plt.figure(figsize=(15, 4))

ax1 = plt.subplot(1, 3, 1)
plot_utils.plot_simulation_results(no_zi_low_sep, no_zi_high_sep, ax=ax1, ylabel='Silhouette score', title='0% noisy genes')

ax2 = plt.subplot(1, 3, 2, sharey=ax1)
plot_utils.plot_simulation_results(low_zi_low_sep, low_zi_high_sep, ax=ax2, title='40% noisy genes')

ax3 = plt.subplot(1, 3, 3, sharey=ax1)
_, handles = plot_utils.plot_simulation_results(high_zi_low_sep, high_zi_high_sep, ax=ax3, legend=legend, title='70% noisy genes')

plt.legend(handles, legend, labelspacing=0.5, bbox_to_anchor=(1.3, 0.9), frameon=True)
_ = [h.set_visible(False) for h in handles]

plt.show()
fig.savefig('../scripts/simulations/assumptions_validation/sparsity/output/silhouette.png', bbox_inches='tight')

# %% [markdown]
# # Data log-likelihood

# %%
dll_gap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/dll_gap_scores.npy')
dll_zigap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/dll_zigap_scores.npy')
dll_szigap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/dll_szigap_scores.npy')

# %%
# Prepare arrays to plot
no_zi_low_sep = [dll_gap_scores[0, 0, :], dll_zigap_scores[0, 0, :], dll_szigap_scores[0, 0, :]]
no_zi_high_sep = [dll_gap_scores[0, 1, :], dll_zigap_scores[0, 1, :], dll_szigap_scores[0, 1, :]]

low_zi_low_sep = [dll_gap_scores[1, 0, :], dll_zigap_scores[1, 0, :], dll_szigap_scores[1, 0, :]]
low_zi_high_sep = [dll_gap_scores[1, 1, :], dll_zigap_scores[1, 1, :], dll_szigap_scores[1, 1, :]]

high_zi_low_sep = [dll_gap_scores[2, 0, :], dll_zigap_scores[2, 0, :], dll_szigap_scores[2, 0, :]]
high_zi_high_sep = [dll_gap_scores[2, 1, :], dll_zigap_scores[2, 1, :], dll_szigap_scores[2, 1, :]]

# %%
# Plot silhouette scores
legend=['GaP', 'ZIGaP', 'SZIGaP']
fig = plt.figure(figsize=(15, 4))

ax1 = plt.subplot(1, 3, 1)
plot_utils.plot_simulation_results(no_zi_low_sep, no_zi_high_sep, ax=ax1, ylabel='Train data log-likelihood', title='0% noisy genes')

ax2 = plt.subplot(1, 3, 2, sharey=ax1)
plot_utils.plot_simulation_results(low_zi_low_sep, low_zi_high_sep, ax=ax2, title='40% noisy genes')

ax3 = plt.subplot(1, 3, 3, sharey=ax1)
_, handles = plot_utils.plot_simulation_results(high_zi_low_sep, high_zi_high_sep, ax=ax3, legend=legend, title='70% noisy genes')

plt.legend(handles, legend, labelspacing=0.5, bbox_to_anchor=(1.3, 0.9), frameon=True)
_ = [h.set_visible(False) for h in handles]

plt.show()
fig.savefig('../scripts/simulations/assumptions_validation/sparsity/output/dll.png', bbox_inches='tight')

# %% [markdown]
# # Held-out data log-likelihood

# %%
holl_gap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/holl_gap_scores.npy')
holl_zigap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/holl_zigap_scores.npy')
holl_szigap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/holl_szigap_scores.npy')

# %%
# Prepare arrays to plot
no_zi_low_sep = [holl_gap_scores[0, 0, :], holl_zigap_scores[0, 0, :], holl_szigap_scores[0, 0, :]]
no_zi_high_sep = [holl_gap_scores[0, 1, :], holl_zigap_scores[0, 1, :], holl_szigap_scores[0, 1, :]]

low_zi_low_sep = [holl_gap_scores[1, 0, :], holl_zigap_scores[1, 0, :], holl_szigap_scores[1, 0, :]]
low_zi_high_sep = [holl_gap_scores[1, 1, :], holl_zigap_scores[1, 1, :], holl_szigap_scores[1, 1, :]]

high_zi_low_sep = [holl_gap_scores[2, 0, :], holl_zigap_scores[2, 0, :], holl_szigap_scores[2, 0, :]]
high_zi_high_sep = [holl_gap_scores[2, 1, :], holl_zigap_scores[2, 1, :], holl_szigap_scores[2, 1, :]]

# %%
# Plot silhouette scores
legend=['GaP', 'ZIGaP', 'SZIGaP']
fig = plt.figure(figsize=(15, 4))

ax1 = plt.subplot(1, 3, 1)
plot_utils.plot_simulation_results(no_zi_low_sep, no_zi_high_sep, ax=ax1, ylabel='Held-out data log-likelihood', title='0% noisy genes')

ax2 = plt.subplot(1, 3, 2, sharey=ax1)
plot_utils.plot_simulation_results(low_zi_low_sep, low_zi_high_sep, ax=ax2, title='40% noisy genes ZI')

ax3 = plt.subplot(1, 3, 3, sharey=ax1)
_, handles = plot_utils.plot_simulation_results(high_zi_low_sep, high_zi_high_sep, ax=ax3, legend=legend, title='70% noisy genes ZI')

plt.legend(handles, legend, labelspacing=0.5, bbox_to_anchor=(1.3, 0.9), frameon=True)
_ = [h.set_visible(False) for h in handles]

plt.show()
fig.savefig('../scripts/simulations/assumptions_validation/sparsity/output/holl.png', bbox_inches='tight')

# %% [markdown]
# # Dropout identification accuracy

# %%
dropid_zigap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/dropid_zigap_scores.npy')
dropid_szigap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/dropid_szigap_scores.npy')

# %%
# Prepare arrays to plot
no_zi_low_sep = [dropid_zigap_scores[0, 0, :], dropid_szigap_scores[0, 0, :]]
no_zi_high_sep = [dropid_zigap_scores[0, 1, :], dropid_szigap_scores[0, 1, :]]

low_zi_low_sep = [dropid_zigap_scores[1, 0, :], dropid_szigap_scores[1, 0, :]]
low_zi_high_sep = [dropid_zigap_scores[1, 1, :], dropid_szigap_scores[1, 1, :]]

high_zi_low_sep = [dropid_zigap_scores[2, 0, :], dropid_szigap_scores[2, 0, :]]
high_zi_high_sep = [dropid_zigap_scores[2, 1, :], dropid_szigap_scores[2, 1, :]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-f7333fe96c3c> in <module>()
#       6 low_zi_high_sep = [dropid_zigap_scores[1, 1, :], dropid_szigap_scores[1, 1, :]]
#       7
# ----> 8 high_zi_low_sep = [dropid_zigap_scores[2, 0, :], dropid_szigap_scores[2, 0, :]]
#       9 high_zi_high_sep = [dropid_zigap_scores[2, 1, :], dropid_szigap_scores[2, 1, :]]
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
# Plot silhouette scores
legend=['ZIGaP', 'SZIGaP']
fig = plt.figure(figsize=(10, 4))

ax1 = plt.subplot(1, 2, 1)
plot_utils.plot_simulation_results(no_zi_low_sep, no_zi_high_sep, ax=ax1, ylabel='Dropout identification accuracy', title='0% noisy genes')

ax2 = plt.subplot(1, 2, 2, sharey=ax1)
plot_utils.plot_simulation_results(low_zi_low_sep, low_zi_high_sep, ax=ax2, title='40% noisy genes')

ax3 = plt.subplot(1, 2, 3, sharey=ax1)
_, handles = plot_utils.plot_simulation_results(high_zi_low_sep, high_zi_high_sep, ax=ax2, legend=legend, title='70% noisy genes')

plt.legend(handles, legend, labelspacing=0.5, bbox_to_anchor=(1.3, 0.9), frameon=True)
_ = [h.set_visible(False) for h in handles]

plt.show()
fig.savefig('../scripts/simulations/assumptions_validation/sparsity/output/dropid.png', bbox_inches='tight')

# %% [markdown]
# # Dropout imputation error

# %%
dropimp_gap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/dropimp_gap_scores.npy')
dropimp_zigap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/dropimp_zigap_scores.npy')
dropimp_szigap_scores = np.load('../scripts/simulations/assumptions_validation/sparsity/output/dropimp_szigap_scores.npy')

# %%
# Prepare arrays to plot
no_zi_low_sep = [dropimp_gap_scores[0, 0, :], dropimp_zigap_scores[0, 0, :], dropimp_szigap_scores[0, 0, :]]
no_zi_high_sep = [dropimp_gap_scores[0, 1, :], dropimp_zigap_scores[0, 1, :], dropimp_szigap_scores[0, 1, :]]

low_zi_low_sep = [dropimp_gap_scores[1, 0, :], dropimp_zigap_scores[1, 0, :], dropimp_szigap_scores[1, 0, :]]
low_zi_high_sep = [dropimp_gap_scores[1, 1, :], dropimp_zigap_scores[1, 1, :], dropimp_szigap_scores[1, 1, :]]

high_zi_low_sep = [dropimp_gap_scores[2, 0, :], dropimp_zigap_scores[2, 0, :], dropimp_szigap_scores[2, 0, :]]
high_zi_high_sep = [dropimp_gap_scores[2, 1, :], dropimp_zigap_scores[2, 1, :], dropimp_szigap_scores[2, 1, :]]

# %%
# Plot silhouette scores
legend=['GaP', 'ZIGaP', 'SZIGaP']
fig = plt.figure(figsize=(10, 4))

ax1 = plt.subplot(1, 2, 1)
plot_utils.plot_simulation_results(no_zi_low_sep, no_zi_high_sep, ax=ax1, ylabel='Dropout imputation error', title='0% noisy genes')

ax2 = plt.subplot(1, 2, 2, sharey=ax1)
plot_utils.plot_simulation_results(low_zi_low_sep, low_zi_high_sep, ax=ax2, title='40% noisy genes')

ax3 = plt.subplot(1, 2, 3, sharey=ax1)
_, handles = plot_utils.plot_simulation_results(high_zi_low_sep, high_zi_high_sep, ax=ax2, legend=legend, title='70% noisy genes')

plt.legend(handles, legend, labelspacing=0.5, bbox_to_anchor=(1.3, 0.9), frameon=True)
_ = [h.set_visible(False) for h in handles]

plt.show()
fig.savefig('../scripts/simulations/assumptions_validation/sparsity/output/dropimp.png', bbox_inches='tight')
