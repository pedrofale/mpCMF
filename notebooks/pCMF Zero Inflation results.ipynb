# %%
# %matplotlib inline

from pCMF.misc import plot_utils

import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns
sns.set_style('whitegrid')

# %% [markdown]
# # Silhouette scores

# %%
silh_pca_scores = np.load('../scripts/simulations/zero_inflation/prior_sensitivity/output/silh_pca_scores.npy')
silh_spca_scores = np.load('../scripts/simulations/zero_inflation/prior_sensitivity/output/silh_spca_scores.npy')
silh_gap_scores = np.load('../scripts/simulations/zero_inflation/prior_sensitivity/output/silh_gap_scores.npy')
silh_zigap_scores = np.load('../scripts/simulations/zero_inflation/prior_sensitivity/output/silh_zigap_scores.npy')

# %%
# Prepare arrays to plot
no_zi_low_sep = [silh_pca_scores[0, 0, :], silh_spca_scores[0, 0, :], silh_gap_scores[0, 0, :], silh_zigap_scores[0, 0, :]]
no_zi_high_sep = [silh_pca_scores[0, 1, :], silh_spca_scores[0, 1, :], silh_gap_scores[0, 1, :], silh_zigap_scores[0, 1, :]]

low_zi_low_sep = [silh_pca_scores[1, 0, :], silh_spca_scores[1, 0, :], silh_gap_scores[1, 0, :], silh_zigap_scores[1, 0, :]]
low_zi_high_sep = [silh_pca_scores[1, 1, :], silh_spca_scores[1, 1, :], silh_gap_scores[1, 1, :], silh_zigap_scores[1, 1, :]]

high_zi_low_sep = [silh_pca_scores[2, 0, :], silh_spca_scores[2, 0, :], silh_gap_scores[2, 0, :], silh_zigap_scores[2, 0, :]]
high_zi_high_sep = [silh_pca_scores[2, 1, :], silh_spca_scores[2, 1, :], silh_gap_scores[2, 1, :], silh_zigap_scores[2, 1, :]]

# %%
# Plot silhouette scores
legend=['PCA', 'SPCA', 'GaP', 'ZIGaP']
fig = plt.figure(figsize=(15, 4))

ax1 = plt.subplot(1, 3, 1)
plot_utils.plot_simulation_results(no_zi_low_sep, no_zi_high_sep, ax=ax1, ylabel='Silhouette score', title='No ZI')

ax2 = plt.subplot(1, 3, 2, sharey=ax1)
plot_utils.plot_simulation_results(low_zi_low_sep, low_zi_high_sep, ax=ax2, title='Low ZI')

ax3 = plt.subplot(1, 3, 3, sharey=ax1)
_, handles = plot_utils.plot_simulation_results(high_zi_low_sep, high_zi_high_sep, ax=ax3, legend=legend, title='High ZI')

plt.legend(handles, legend, labelspacing=0.5, bbox_to_anchor=(1.3, 0.9), frameon=True)
_ = [h.set_visible(False) for h in handles]

plt.show()
fig.savefig('../scripts/simulations/zero_inflation/prior_sensitivity/output/silhouette.png', bbox_inches='tight')

# %% [markdown]
# # Data log-likelihood

# %%
dll_gap_scores = np.load('../scripts/simulations/zero_inflation/prior_sensitivity/output/dll_gap_scores.npy')
dll_zigap_scores = np.load('../scripts/simulations/zero_inflation/prior_sensitivity/output/dll_zigap_scores.npy')

# %%
# Prepare arrays to plot
no_zi_low_sep = [dll_gap_scores[0, 0, :], dll_zigap_scores[0, 0, :]]
no_zi_high_sep = [dll_gap_scores[0, 1, :], dll_zigap_scores[0, 1, :]]

low_zi_low_sep = [dll_gap_scores[1, 0, :], dll_zigap_scores[1, 0, :]]
low_zi_high_sep = [dll_gap_scores[1, 1, :], dll_zigap_scores[1, 1, :]]

high_zi_low_sep = [dll_gap_scores[2, 0, :], dll_zigap_scores[2, 0, :]]
high_zi_high_sep = [dll_gap_scores[2, 1, :], dll_zigap_scores[2, 1, :]]

# %%
# Plot silhouette scores
legend=['GaP', 'ZIGaP']
fig = plt.figure(figsize=(15, 4))

ax1 = plt.subplot(1, 3, 1)
plot_utils.plot_simulation_results(no_zi_low_sep, no_zi_high_sep, ax=ax1, ylabel='Data log-likelihood', title='No ZI')

ax2 = plt.subplot(1, 3, 2, sharey=ax1)
plot_utils.plot_simulation_results(low_zi_low_sep, low_zi_high_sep, ax=ax2, title='Low ZI')

ax3 = plt.subplot(1, 3, 3, sharey=ax1)
_, handles = plot_utils.plot_simulation_results(high_zi_low_sep, high_zi_high_sep, ax=ax3, legend=legend, title='High ZI')

plt.legend(handles, legend, labelspacing=0.5, bbox_to_anchor=(1.3, 0.9), frameon=True)
_ = [h.set_visible(False) for h in handles]

plt.show()
fig.savefig('../scripts/simulations/zero_inflation/prior_sensitivity/output/dll.png', bbox_inches='tight')
# Out:
# /home/pferreira/pCMF/venv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:1847: RuntimeWarning: invalid value encountered in double_scalars
#   stats['iqr'] = q3 - q1
# /home/pferreira/pCMF/venv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:1872: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = np.compress(x <= hival, x)
# /home/pferreira/pCMF/venv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:1879: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = np.compress(x >= loval, x)

# %% [markdown]
# # Held-out data log-likelihood

# %%
holl_gap_scores = np.load('../scripts/simulations/zero_inflation/prior_sensitivity/output/holl_gap_scores.npy')
holl_zigap_scores = np.load('../scripts/simulations/zero_inflation/prior_sensitivity/output/holl_zigap_scores.npy')

# %%
# Prepare arrays to plot
no_zi_low_sep = [holl_gap_scores[0, 0, :], holl_zigap_scores[0, 0, :]]
no_zi_high_sep = [holl_gap_scores[0, 1, :], holl_zigap_scores[0, 1, :]]

low_zi_low_sep = [holl_gap_scores[1, 0, :], holl_zigap_scores[1, 0, :]]
low_zi_high_sep = [holl_gap_scores[1, 1, :], holl_zigap_scores[1, 1, :]]

high_zi_low_sep = [holl_gap_scores[2, 0, :], holl_zigap_scores[2, 0, :]]
high_zi_high_sep = [holl_gap_scores[2, 1, :], holl_zigap_scores[2, 1, :]]

# %%
# Plot silhouette scores
legend=['GaP', 'ZIGaP']
fig = plt.figure(figsize=(15, 4))

ax1 = plt.subplot(1, 3, 1)
plot_utils.plot_simulation_results(no_zi_low_sep, no_zi_high_sep, ax=ax1, ylabel='Held-out data log-likelihood', title='No ZI')

ax2 = plt.subplot(1, 3, 2, sharey=ax1)
plot_utils.plot_simulation_results(low_zi_low_sep, low_zi_high_sep, ax=ax2, title='Low ZI')

ax3 = plt.subplot(1, 3, 3, sharey=ax1)
_, handles = plot_utils.plot_simulation_results(high_zi_low_sep, high_zi_high_sep, ax=ax3, legend=legend, title='High ZI')

plt.legend(handles, legend, labelspacing=0.5, bbox_to_anchor=(1.3, 0.9), frameon=True)
_ = [h.set_visible(False) for h in handles]

plt.show()
fig.savefig('../scripts/simulations/zero_inflation/prior_sensitivity/output/holl.png', bbox_inches='tight')

# %% [markdown]
# # Dropout identification accuracy

# %%
dropid_zigap_scores = np.load('../scripts/simulations/zero_inflation/prior_sensitivity/output/dropid_zigap_scores.npy')

# %%
# Prepare arrays to plot
low_zi_low_sep = [dropid_zigap_scores[0, 0, :]]
low_zi_high_sep = [dropid_zigap_scores[0, 1, :]]

high_zi_low_sep = [dropid_zigap_scores[1, 0, :]]
high_zi_high_sep = [dropid_zigap_scores[1, 1, :]]

# %%
# Plot silhouette scores
legend=['ZIGaP']
fig = plt.figure(figsize=(10, 4))

ax1 = plt.subplot(1, 2, 1)
plot_utils.plot_simulation_results(low_zi_low_sep, low_zi_high_sep, ax=ax1, ylabel='Dropout identification accuracy', title='Low ZI')

ax2 = plt.subplot(1, 2, 2, sharey=ax1)
_, handles = plot_utils.plot_simulation_results(high_zi_low_sep, high_zi_high_sep, ax=ax2, legend=legend, title='High ZI')

plt.legend(handles, legend, labelspacing=0.5, bbox_to_anchor=(1.3, 0.9), frameon=True)
_ = [h.set_visible(False) for h in handles]

plt.show()
fig.savefig('../scripts/simulations/zero_inflation/prior_sensitivity/output/dropid.png', bbox_inches='tight')

# %% [markdown]
# # Dropout imputation error

# %%
dropimp_gap_scores = np.load('../scripts/simulations/zero_inflation/prior_sensitivity/output/dropimp_gap_scores.npy')
dropimp_zigap_scores = np.load('../scripts/simulations/zero_inflation/prior_sensitivity/output/dropimp_zigap_scores.npy')

# %%
# Prepare arrays to plot
low_zi_low_sep = [dropimp_gap_scores[0, 0, :], dropimp_zigap_scores[0, 0, :]]
low_zi_high_sep = [dropimp_gap_scores[0, 1, :], dropimp_zigap_scores[0, 1, :]]

high_zi_low_sep = [dropimp_gap_scores[1, 0, :], dropimp_zigap_scores[1, 0, :]]
high_zi_high_sep = [dropimp_gap_scores[1, 1, :], dropimp_zigap_scores[1, 1, :]]

# %%
# Plot silhouette scores
legend=['GaP', 'ZIGaP']
fig = plt.figure(figsize=(10, 4))

ax1 = plt.subplot(1, 2, 1)
plot_utils.plot_simulation_results(low_zi_low_sep, low_zi_high_sep, ax=ax1, ylabel='Dropout imputation error', title='Low ZI')

ax2 = plt.subplot(1, 2, 2, sharey=ax1)
_, handles = plot_utils.plot_simulation_results(high_zi_low_sep, high_zi_high_sep, ax=ax2, legend=legend, title='High ZI')

plt.legend(handles, legend, labelspacing=0.5, bbox_to_anchor=(1.3, 0.9), frameon=True)
_ = [h.set_visible(False) for h in handles]

plt.show()
fig.savefig('../scripts/simulations/zero_inflation/prior_sensitivity/output/dropimp.png', bbox_inches='tight')
